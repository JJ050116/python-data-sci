# %% [markdown]
# # Challenge 05 — ประเทศใดมี pace เฉลี่ยสูง?
#
# **Week 05 · Analysis · 20–30 นาที**
#
# ## ภารกิจ
# บทเรียนใช้ `league` และ `overall` แล้ว — หาค่า `pace` เฉลี่ยแยกตาม `nationality` แล้วเรียงผลจากมากไปน้อย
#
# ## จุดคิดสำคัญ
# ค่าเฉลี่ยคือภาพรวมของกลุ่ม ไม่ได้หมายความว่านักเตะทุกคนในประเทศนั้นเร็วเท่ากัน

# %%
import pandas as pd
df = pd.read_csv("../data/footballers.csv")

# ดูว่ามีประเทศใดบ้างก่อน
df["nationality"].value_counts()

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# ใช้ `groupby` เพื่อแบ่งตารางเป็นกลุ่ม และใช้ `mean` เพื่อคำนวณค่าเฉลี่ย
#
# **Debug checkpoint:** ถ้าใช้ชื่อ `nationalities` แทน `nationality` จะเกิด Error ชนิดใด? ตรวจชื่อจริงด้วย `df.columns`

# %%
# TODO: groupby nationality
# TODO: เลือก pace และหา mean
# TODO: sort จากมากไปน้อย

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] ผลลัพธ์มี 1 ค่าเฉลี่ยต่อ 1 ลีก
# - [ ] เรียง descending
# - [ ] เขียนข้อสรุปที่มีคำว่า “ในชุดข้อมูลนี้”
