# %% [markdown]
# # Challenge 07 — เขียนข้อสรุปที่ไม่เกินข้อมูล
#
# **Week 07 · Data story · 20–30 นาที**
#
# ## ภารกิจ
# เลือกกราฟจาก Week 06 หนึ่งรูป แล้วเขียน 3 ประโยค:
# 1. สิ่งที่เห็น
# 2. หลักฐานจากกราฟ
# 3. สิ่งที่ยังสรุปไม่ได้
#
# ## Debug checkpoint
# ระวังคำว่า “พิสูจน์” หรือ “ทุกคน” เมื่อข้อมูลมีเพียง 20 แถว — ให้ระบุขอบเขตด้วยคำว่า “ในชุดข้อมูลนี้”

# %%
import pandas as pd
df = pd.read_csv("../data/footballers.csv")

# ใช้ cell นี้ตรวจขอบเขตของข้อมูลก่อนสรุป
print("จำนวนแถว:", len(df))
print("จำนวนลีก:", df["league"].nunique())

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# - สิ่งที่เห็น: ...
# - หลักฐาน: ...
# - สิ่งที่ยังสรุปไม่ได้: ...
#
# ห้ามอ้างข้อมูลนอกตารางโดยไม่มีหลักฐาน

# %%
# TODO: เขียน 3 ประโยคเป็น comment หรือ print()

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] มีตัวเลข/ชื่อจากกราฟเป็นหลักฐาน
# - [ ] บอกข้อจำกัดของชุดข้อมูล
# - [ ] ใช้ภาษาที่คนไม่เขียนโค้ดเข้าใจได้
