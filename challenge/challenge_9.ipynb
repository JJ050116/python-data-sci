# %% [markdown]
# # Challenge 09 — Mini project: ตั้งคำถามและเตรียมข้อมูล
#
# **Week 09 · Mini project · 2 ชั่วโมง**
#
# ## ภารกิจ
# เลือกคำถาม 1 ข้อที่ตอบได้จาก `footballers.csv` เช่น “ตำแหน่งใดมี `value_millions` เฉลี่ยสูงสุด?”
#
# เขียนแผน 4 ส่วน:
# 1. คำถาม
# 2. คอลัมน์ที่จะใช้
# 3. สิ่งที่ต้องตรวจ/clean
# 4. กราฟที่เลือกและเหตุผล
#
# ## จุดตรวจ
# คำถามต้องตอบได้จากคอลัมน์ที่มีจริง ไม่ใช่คำถามที่ต้องเดาข้อมูลนอกไฟล์

# %%
import pandas as pd
df = pd.read_csv("../data/footballers.csv")

# ตรวจข้อมูลก่อนวางแผน
display(df.head(3))
df.info()

# %% [markdown]
# ### แผนงานของคุณ
# - **คำถาม:**
# - **คอลัมน์:**
# - **การ clean:**
# - **กราฟและเหตุผล:**
#
# ### Debug checkpoint
# หาก code บอก `KeyError` ให้กลับไปตรวจ `df.columns` ก่อนเปลี่ยนโค้ด

# %%
# TODO: เขียนโค้ดสำรวจ/clean ที่จำเป็นสำหรับคำถามของคุณ

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] คำถามใช้คอลัมน์ที่มีจริง
# - [ ] ระบุอย่างน้อย 1 จุดที่จะตรวจคุณภาพข้อมูล
# - [ ] กราฟตอบคำถาม ไม่ใช่เลือกเพราะสวย
