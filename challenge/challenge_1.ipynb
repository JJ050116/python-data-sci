# %% [markdown]
# # Challenge 01 — เปิดไฟล์ข้อมูลอย่างเป็นระบบ
#
# **Week 01 · 20–30 นาที**  \nเป้าหมาย: อ่าน CSV, ดูตัวอย่างข้อมูล และตรวจขนาดของตาราง
#
# ## ภารกิจ
# 1. อ่านไฟล์ `footballers.csv` เข้าเก็บในตัวแปร `df`
# 2. แสดง 3 แถวแรก
# 3. แสดงจำนวนแถวและคอลัมน์ของตาราง
#
# ## Debug checkpoint
# ใน cell ด้านล่างมี path ที่ผิดซ่อนอยู่ ลองรันก่อน อ่านบรรทัดสุดท้ายของ Error แล้วแก้ด้วยตัวเอง
#
# > ห้ามเดาจำนวนข้อมูลจากสิ่งที่เห็นใน `head()` — ใช้ `df.shape` ตรวจสอบ

# %%
import pandas as pd

# รัน cell นี้ก่อน แล้วอ่าน Error
df = pd.read_csv("data/footballers.csv")

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# อธิบายสั้น ๆ ว่า Error บอกอะไร และคุณเปลี่ยนอะไรเพื่อแก้ปัญหา

# %%
# TODO: อ่านไฟล์ให้ถูก path
# TODO: แสดง 3 แถวแรก
# TODO: แสดงขนาดตาราง

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] `df` เป็นตาราง DataFrame
# - [ ] แสดง 3 แถวแรก ไม่ใช่ทั้งไฟล์
# - [ ] บอกได้ว่าค่า 2 ตัวใน `shape` หมายถึงอะไร
