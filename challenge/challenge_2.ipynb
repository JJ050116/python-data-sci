# %% [markdown]
# # Challenge 02 — เลือกและเปลี่ยนชื่อคอลัมน์
#
# **Week 02 · 20–30 นาที**  \nเป้าหมาย: เลือกเฉพาะข้อมูลที่จำเป็นและสร้างตารางใหม่โดยไม่แก้ `df` เดิม
#
# ## ภารกิจ
# สร้างตัวแปร `summary` ที่มีเพียง `name`, `club`, `overall` แล้วเปลี่ยนชื่อ `overall` เป็น `rating`
#
# ## Debug checkpoint
# cell ที่เตรียมให้สะกดชื่อคอลัมน์ผิด 1 จุด รันแล้วดูว่า `KeyError` กำลังหาอะไรไม่เจอ

# %%
import pandas as pd
df = pd.read_csv("../data/footballers.csv")

# รันก่อน แล้วอ่าน KeyError
summary = df[["name", "club", "Overall"]]

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# ใบ้: ใช้ `df.columns` ตรวจชื่อจริงก่อนแก้ ไม่เปลี่ยนชื่อจากการเดา

# %%
# TODO: เลือก 3 คอลัมน์ที่ถูกต้อง
# TODO: เปลี่ยน overall เป็น rating
# TODO: แสดง 5 แถวแรกของ summary

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] `df.columns` ยังมีชื่อ `overall`
# - [ ] `summary.columns` มีชื่อ `rating`
# - [ ] อธิบายได้ว่า KeyError เกี่ยวกับชื่อคอลัมน์อย่างไร
