# %% [markdown]
# ### จากข้อมูลตัวอย่างด้านล่าง ให้ตอบคำถามต่อไปนี้:
#
# 1. แสดงข้อมูล 5 แถวแรก (CSV file)
# 2. หาคะแนนเฉลี่ยของนักเรียนแต่ละแผนก
# 3. หานักเรียนที่มีคะแนนสูงสุด
# 4. กรองนักเรียนที่มีคะแนนมากกว่า 80 และเข้าชั้นมากกว่า 90%
#
# ให้เขียนคำตอบใน cell ถัดไป
# ```
# data = [
#     {"name": "Alice", "department": "CS", "score": 85, "attendance": 95},
#     {"name": "Bob", "department": "Math", "score": 78, "attendance": 88},
#     {"name": "Carol", "department": "CS", "score": 92, "attendance": 90},
#     {"name": "Dora", "department": "Math", "score": 88, "attendance": 91},
#     {"name": "Eve", "department": "CS", "score": 76, "attendance": 87},
# ]
# ```

# %%
data = [
    {"name": "Alice", "department": "CS", "score": 85, "attendance": 95},
    {"name": "Bob", "department": "Math", "score": 78, "attendance": 88},
    {"name": "Carol", "department": "CS", "score": 92, "attendance": 90},
    {"name": "Dora", "department": "Math", "score": 88, "attendance": 91},
    {"name": "Eve", "department": "CS", "score": 76, "attendance": 87},
]

# หาคะแนนเฉลี่ยของนักเรียนแต่ละแผนก

test_0 = data[0]
test_1 = data[1]
test_2 = data[2]
test_3 = data[3]
test_4 = data[4]

print(test_0["score"], test_1["score"])

department_Math = []
department_CS = []

print()
# Out:
# 85 78
