# %% [markdown]
# # Challenge 10 — Mini project: รายงานฉบับย่อ
#
# **Week 10 · Mini project · 2 ชั่วโมง**
#
# ## ภารกิจ
# ทำ Notebook รายงานที่รันจากบนลงล่างได้ ประกอบด้วย:
# 1. คำถาม
# 2. การตรวจและ clean ข้อมูล
# 3. การวิเคราะห์
# 4. กราฟอย่างน้อย 1 รูป
# 5. สรุป 3 ประโยค: คำตอบ, หลักฐาน, ข้อจำกัด
#
# ## Debug checkpoint สำคัญ
# เลือก **Restart Kernel → Run All** หากพัง แปลว่า Notebook พึ่งพาลำดับ cell ที่ไม่ถูกต้อง หรือมีตัวแปรที่ยังไม่ถูกสร้าง

# %% [markdown]
# ### รายงานของคุณ
# - **คำถาม:**
# - **ผลที่พบ:**
# - **หลักฐานจากข้อมูล/กราฟ:**
# - **ข้อจำกัด:**

# %%
# TODO: import libraries
# TODO: read data
# TODO: clean / analyze
# TODO: create graph
# TODO: print or write your conclusion

# %% [markdown]
# ### Rubric ย่อ (10 คะแนน)
# - 2 คะแนน: คำถามชัดและตอบได้จากข้อมูล
# - 2 คะแนน: ตรวจ/จัดการข้อมูลก่อนวิเคราะห์
# - 2 คะแนน: โค้ดรันจากบนลงล่างได้
# - 2 คะแนน: กราฟอ่านง่าย มีชื่อแกน
# - 2 คะแนน: สรุปมีหลักฐานและข้อจำกัด
#
# ### Check ก่อนส่ง
# - [ ] Restart Kernel แล้ว Run All ผ่าน
# - [ ] ไม่มี output เก่าที่ทำให้เข้าใจผิด
# - [ ] ผู้อ่านที่ไม่เขียนโค้ดเข้าใจข้อสรุปได้
