# %% [markdown]
# # Challenge 03 — อายุที่หายไป
#
# **Week 03 · Cleaning data · 20–30 นาที**
#
# ## ภารกิจ
# บทเรียนใช้ `height_cm` ไปแล้ว — Challenge นี้ให้ใช้คอลัมน์ `age` แทน: ตรวจว่ามีข้อมูลหายกี่จุด แล้วสร้าง `clean_df` ที่แทนค่าหายด้วยค่ากลาง (median)
#
# ## Debug checkpoint
# อย่าแทนค่าหายด้วย 0 โดยอัตโนมัติ: อายุ 0 ปีไม่ใช่ข้อมูลจริง และจะทำให้ค่าเฉลี่ยเพี้ยน

# %%
import pandas as pd
df = pd.read_csv("../data/footballers.csv")

# สำรวจข้อมูลหายก่อนทำอย่างอื่น
df["age"].isna().sum()

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# อธิบายด้วยว่า median คืออะไร และเหตุใดจึงเหมาะกว่าค่า 0 ในกรณีนี้

# %%
# TODO: copy df เป็น clean_df
# TODO: หาค่า median ของ age
# TODO: fillna และตรวจว่าค่าหายเหลือเท่าไร

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] `df` เดิมยังไม่ถูกแก้
# - [ ] `clean_df["age"].isna().sum()` เป็น 0
# - [ ] ไม่ได้ใช้ 0 เป็นค่าทดแทน
