# %% [markdown]
# # Challenge 06 — กราฟที่เปรียบเทียบได้
#
# **Week 06 · Visualization · 20–30 นาที**
#
# ## ภารกิจ
# สร้าง bar chart ของนักเตะ 5 คนที่มี `overall` สูงสุด โดยแกน X เป็นชื่อ และแกน Y เป็น `overall`
#
# ## Debug checkpoint
# ข้อมูลแกน X และแกน Y ต้องมาจากตาราง `top5` เดียวกัน มิฉะนั้นจำนวนข้อมูลอาจไม่เท่ากัน

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("../data/footballers.csv")

# TODO: สร้าง top5 ด้วย nlargest

# %% [markdown]
# ### เขียนคำตอบของคุณด้านล่าง
# เพิ่มชื่อแกน Y และหมุนชื่อแกน X เพื่อให้คนอ่านกราฟได้ง่าย
#
# **ลองทำให้พังเพื่ออ่าน Error:** ใช้ `df["name"]` เป็นแกน X แต่ใช้ `top5["overall"]` เป็นแกน Y แล้วอ่านข้อความ Error

# %%
# TODO: plt.bar(top5[...], top5[...])
# TODO: ตั้ง ylabel
# TODO: หมุนชื่อแกน X
# TODO: plt.show()

# %% [markdown]
# ### Check ก่อนส่ง
# - [ ] มีแท่งกราฟ 5 แท่ง
# - [ ] ชื่อและคะแนนมาจาก `top5` เดียวกัน
# - [ ] กราฟมีชื่อแกน Y
