# %%
import pandas as pd

# %% [markdown]
# #### Library Pandas in python
# - Analy data
# - Cleaning data
# - Design (Table or data)
# #### What about library Pandas reading the data file?
# - CSV
# - Excel

# %%
# Mockup expenses
data = {
    "list" : ["Food", "Travel", "Game"],
    "price": [100, 200, 300]
}

# %% [markdown]
# function .DataFrame() = convert dictionary to Table

# %%
result = pd.DataFrame(data)

result
# Out:
#      list  price
# 0    Food    100
# 1  Travel    200
# 2    Game    300
