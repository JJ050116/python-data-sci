# %%
for player in ['Messi', 'Ronaldo', 'Mbappe']:
    print(player)
# Out:
# Messi
# Ronaldo
# Mbappe

# %%
ages = [12, 13, 13, 14, 12]
total = 0
for x in ages:
    total += x

average = total / len(ages)

print("Age average: ", average)
# Out:
# Age average:  12.8
